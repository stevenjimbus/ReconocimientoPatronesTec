# %% [markdown]
# # InvCorta-1

# %% [markdown]
# Crear una notebook llamada InvCorta-1.ipynb, dicha notebook debe contener las libreras: numpy, matplotlib, scikit-learn, pandas, jupyter notebook (esta ultima en caso de que sea ambiente local) como mnimo, puede agregar otras libs que considere necesario. La notebook debe tener como mnimo: Texto de varios tamanos, figuras de funciones generadas por codigo, imagenes externas, codigos simples que desplieguen algun valor y ecuaciones (tipo LATEX). El entregable consiste en el url de la notebook InvCorta-1.ipynb en GITHUB. Enviar por email (fmeza@itcr.ac.cr) el url a mas tardar el jueves 03 de junio antes de las 3:59pm, envos pasado el limite de entrega se aplicara la penalizacion discutida en clase.

# %% [markdown]
# # Texto de varios tamanos
# ## Texto 2
# ### Texto 3
# #### Texto 4

# %%
import numpy as np
import sklearn as sk
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Figuras de funciones generadas por codigo

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='About as simple as it gets, folks')
ax.grid()

fig.savefig("test.png")
plt.show()

# %% [markdown]
# ## Imagenes externas

# %%
from IPython import display
display.Image("https://upload.wikimedia.org/wikipedia/commons/thumb/3/3c/Giant_Panda_2004-03-2.jpg/250px-Giant_Panda_2004-03-2.jpg")

# %% [markdown]
# ## Codigos simples que desplieguen algun valor

# %%
x = 751
y = x + 10
print("El valor de y es", y)
# Out:
# El valor de y es 761

# %% [markdown]
# ## Ecuaciones (tipo LATEX)
#
#
# To insert a mathematical formula we use the dollar symbol $, as follows:
#
#
#
# Euler's identity: $ e^{i \pi} + 1 = 0 $
#
#
#
# To isolate and center the formulas and enter in math display mode, we use 2 dollars symbol:
#
#
#
# Euler's identity: $$ e^{i \pi} + 1 = 0 $$
